# %%
import pandas as pd
# import config
# import tqdm
# import requests 

from ipynb.fs.full.utility import FreeCompetitions, FreeMatches, StatsBombFreeEvents

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data_env = 'github'

# %%
free_comp = FreeCompetitions(env=data_env)

# %%
free_comp
# Out:
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# 13              16         44                    Europe
# 14              16         76                    Europe
# 15              37         42                   England
# ...

# %%
#Only Champions League Matches

matches = FreeMatches(free_comp,env=data_env)

# %%
matches
# Out:
#      match_id  match_date      kick_off  home_score  away_score match_status  \
# 0       22912  2019-06-01  21:00:00.000           0           2    available
# 1       18245  2018-05-26  20:45:00.000           3           1    available
# 2       18244  2017-06-03  20:45:00.000           1           4    available
# 3       18243  2016-05-28  20:45:00.000           1           1    available
# 4       18242  2015-06-06  20:45:00.000           1           3    available
# 5       18241  2014-05-24  20:45:00.000           4           1    available
# 6       18240  2013-05-25  20:45:00.000           1           2    available
# 7       18237  2012-05-19  20:45:00.000           1           1    available
# 8       18236  2011-05-28  20:45:00.000           3           1    available
# 9       18235  2010-05-22  20:45:00.000           0           2    available
# 10    3750201  2009-05-27  20:45:00.000           2           0    available
# ...
